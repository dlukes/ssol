# %%
# %matplotlib notebook

# %%
import nltk
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
def freq(word, text):
    return text.count(word) / len(text) * 1e6

# %%
freq("Ni", text6)
# Out:
# 2770.083102493075

# %%
sent = ["Call", "me", "Ishmael", "."]

# %%
sent.append("Moby")
sent
# Out:
# ['Call', 'me', 'Ishmael', '.', 'Moby']

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
sent4
# Out:
# ['Fellow',
#  '-',
#  'Citizens',
#  'of',
#  'the',
#  'Senate',
#  'and',
#  'of',
#  'the',
#  'House',
#  'of',
#  'Representatives',
#  ':']

# %%
sent1 + sent4
# Out:
# ['Call',
#  'me',
#  'Ishmael',
#  '.',
#  'Fellow',
#  '-',
#  'Citizens',
#  'of',
#  'the',
#  'Senate',
#  'and',
#  'of',
#  'the',
#  'House',
#  'of',
#  'Representatives',
#  ':']

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
sent1.index("Ishmael")
# Out:
# 2

# %%
text6[1600:1625]
# Out:
# ['We',
#  "'",
#  're',
#  'an',
#  'anarcho',
#  '-',
#  'syndicalist',
#  'commune',
#  '.',
#  'We',
#  'take',
#  'it',
#  'in',
#  'turns',
#  'to',
#  'act',
#  'as',
#  'a',
#  'sort',
#  'of',
#  'executive',
#  'officer',
#  'for',
#  'the',
#  'week']

# %%
sent = ["word1", "word2", "word3", "word4", "word5"]

# %%
sent[0]
# Out:
# 'word1'

# %%
sent[1:3]
# Out:
# ['word2', 'word3']

# %%
sent[:3]
# Out:
# ['word1', 'word2', 'word3']

# %%
sent[3:]
# Out:
# ['word4', 'word5']

# %%
sent[0] = "First"
sent
# Out:
# ['First', 'word2', 'word3', 'word4', 'word5']

# %%
sent[1:5] = ["Middle"]
sent
# Out:
# ['First', 'Middle']

# %%
nums = [2, 4, 1, 6, 3]
nums.sort()
nums
# Out:
# [1, 2, 3, 4, 6]

# %%
nums = [2, 4, 1, 6, 3]
sorted(nums)
# Out:
# [1, 2, 3, 4, 6]

# %%
nums
# Out:
# [2, 4, 1, 6, 3]

# %%
name = "Monty"

# %%
name[0]
# Out:
# 'M'

# %%
name[:4]
# Out:
# 'Mont'

# %%
name + name
# Out:
# 'MontyMonty'

# %%
sorted(name)
# Out:
# ['M', 'n', 'o', 't', 'y']

# %%
name.upper()
# Out:
# 'MONTY'

# %%
name
# Out:
# 'Monty'

# %%
name.istitle()
# Out:
# True

# %%
"Monty Python".split()
# Out:
# ['Monty', 'Python']

# %%
" ".join(['Monty', 'Python'])
# Out:
# 'Monty Python'

# %%
pair = (1, 2)

# %%
pair
# Out:
# (1, 2)

# %%
pair[0] = 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-43fb3051a481> in <module>()
# ----> 1 pair[0] = 2
#
# TypeError: 'tuple' object does not support item assignment

# %%
fdist1 = nltk.FreqDist(text6)

# %%
fdist1.most_common(10)
# Out:
# [(':', 1197),
#  ('.', 816),
#  ('!', 801),
#  (',', 731),
#  ("'", 421),
#  ('[', 319),
#  (']', 312),
#  ('the', 299),
#  ('I', 255),
#  ('ARTHUR', 225)]

# %%
fdist1["Ni"]
# Out:
# 47

# %%
fdist1.plot(50, cumulative=True)
# Out:
# <img src="data:image/png;base64,...">

# %%
fdist1.hapaxes()
# Out:
# ['consulted',
#  'couple',
#  'Firstly',
#  'problems',
#  'bangin',
#  'Prepare',
#  'suit',
#  'Mind',
#  'scarper',
#  'regulations',
#  'More',
#  'retreat',
#  'knocked',
#  'Eee',
#  'pray',
#  'voluntarily',
#  'mad',
#  'Packing',
#  'Hyy',
#  'slightly',
#  'Silly',
#  'Assyria',
#  'maintain',
#  'niggets',
#  'oooh',
#  'marrying',
#  'weapon',
#  'dance',
#  'Umhm',
#  'offensive',
#  'pussy',
#  'known',
#  'miserable',
#  'walking',
#  'Bedwere',
#  'Attila',
#  'dunno',
#  'snap',
#  'kicked',
#  'France',
#  'wipers',
#  'tale',
#  'basis',
#  'Practice',
#  'relax',
#  'stood',
#  'magne',
#  'bleeder',
#  'using',
#  'lose',
#  'earth',
#  'imprisoned',
#  'git',
#  'tropical',
#  'behaviour',
#  'sacrifice',
#  'seldom',
#  'ANIMATOR',
#  'imperialist',
#  'badger',
#  'bells',
#  'diaphragm',
#  'temperate',
#  'training',
#  'gave',
#  '13',
#  'employed',
#  'frozen',
#  'became',
#  'sell',
#  'crying',
#  'wiper',
#  'Guy',
#  'Clark',
#  'Every',
# ...

# %%
V = set(text1)

# %%
sorted(t for t in V if len(t) >= 15)
# Out:
# ['Bibliographical',
#  'CIRCUMNAVIGATION',
#  'Ehrenbreitstein',
#  'Mephistophelean',
#  'Physiognomically',
#  'amphitheatrical',
#  'apprehensiveness',
#  'archiepiscopacy',
#  'authoritatively',
#  'cannibalistically',
#  'characteristically',
#  'characteristics',
#  'circumnavigated',
#  'circumnavigating',
#  'circumnavigation',
#  'circumnavigations',
#  'comfortableness',
#  'comprehensively',
#  'comprehensiveness',
#  'conscientiously',
#  'disembowelments',
#  'dissatisfaction',
#  'hermaphroditical',
#  'heterogeneously',
#  'indiscriminately',
#  'indispensableness',
#  'individualities',
#  'individualizing',
#  'indomitableness',
#  'inoffensiveness',
#  'instantaneously',
#  'interchangeably',
#  'internationally',
#  'interrogatively',
#  'intolerableness',
#  'irresistibleness',
#  'miscellaneously',
#  'multitudinously',
#  'notwithstanding',
#  'passionlessness',
#  'perpendicularly',
#  'philanthropists',
#  'philosophically',
#  'phosphorescence',
# ...

# %%
fdist1 = nltk.FreqDist(text1)

# %%
sorted(t for t in V if len(t) > 7 and fdist1[t] > 7)
# Out:
# ['American',
#  'Atlantic',
#  'Bulkington',
#  'Canallers',
#  'Christian',
#  'Commodore',
#  'Consider',
#  'Fedallah',
#  'Greenland',
#  'Guernsey',
#  'Heidelburgh',
#  'Japanese',
#  'Jeroboam',
#  'Leviathan',
#  'Meantime',
#  'Meanwhile',
#  'Mediterranean',
#  'Moreover',
#  'NANTUCKET',
#  'Nantucket',
#  'Nantucketer',
#  'Nantucketers',
#  'Nevertheless',
#  'Porpoise',
#  'Queequeg',
#  'Scoresby',
#  'Sebastian',
#  'Starbuck',
#  'Steelkilt',
#  'Tashtego',
#  'Therefore',
#  'Wherefore',
#  'abounding',
#  'according',
#  'accounted',
#  'accounts',
#  'accursed',
#  'activity',
#  'actually',
#  'additional',
#  'advanced',
#  'advancing',
#  'afternoon',
#  'afterwards',
#  'alongside',
#  'altogether',
#  'ambergris',
#  'answered',
#  'anything',
#  'anywhere',
#  'appalling',
#  'apparently',
#  'apparition',
#  'appearance',
#  'appeared',
#  'approaching',
#  'archangel',
#  'articles',
#  'attached',
#  'attention',
#  'authority',
#  'backward',
# ...

# %%
len_fdist = nltk.FreqDist(len(w) for w in text1)

# %%
len_fdist.plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
from nltk.corpus import stopwords

stop = stopwords.words("english")
stop
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  'her',
#  'hers',
#  'herself',
#  'it',
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
# ...

# %%
fdist1 = nltk.FreqDist(w for w in text1 if w.isalpha()
                       and w.lower() not in stop)

# %%
5 not in [1, 2, 3]
# Out:
# True

# %%
fdist1.plot(20)
# Out:
# <img src="data:image/png;base64,...">
